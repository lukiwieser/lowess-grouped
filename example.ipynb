# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from lowess_grouped import lowess_grouped

# %%
sns.set_theme()

# %%
temp_region = pd.read_csv("./data/temperature-by-region.csv")
temp_region.head(3)
# Out:
#    year  region_code  temperature_anomaly region_name
# 0  1900          2.0            -0.016705      Africa
# 1  1900          9.0            -0.307362     Oceania
# 2  1900         19.0            -0.160803    Americas

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.lineplot(x="year", y="temperature_anomaly", hue="region_name", data=temp_region, ax=ax);

# %%
temp_region = lowess_grouped(temp_region,"year", "temperature_anomaly", "region_name", frac=0.05)

# %%
temp_region.head(3)
# Out:
#    year  region_code  temperature_anomaly region_name  \
# 0  1900          2.0            -0.016705      Africa
# 1  1900          9.0            -0.307362     Oceania
# 2  1900         19.0            -0.160803    Americas
#
#    temperature_anomaly_smooth
# 0                    0.029955
# 1                   -0.292418
# 2                   -0.164371

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.lineplot(x="year", y="temperature_anomaly_smooth", hue="region_name", data=temp_region, ax=ax);
